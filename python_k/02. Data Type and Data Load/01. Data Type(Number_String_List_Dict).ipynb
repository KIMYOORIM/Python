# %%
import datetime

from datetime import datetime as dt2

dt2.now()

currentDate = dt2.now()

# %%
### 2. 시간, 분 정보 불러오기 

#시간, 분 할당
hourVar = currentDate.hour
minutesVar = currentDate.minute
print(hourVar)
print(minutesVar)

### 3. 결과



import datetime

from datetime import datetime as dt3

dt3.now()

currentDate = dt3.now()

1

a= 123

b="123"

print(a+1)

type(b)


### 데이터불러오기

import pandas as pd

pwd

pd.read_csv("../da")

# %%
###문자열의 합
head = "fintech"
tail = "student"
fullstring = head+""+tail
print(fullstring)

# %%
###문자열 곱
print("*"*20+"문자열 연산 프로그램"+"*"*20)

# %%
###문자열 인덱싱 0부터 시작
yearweek = "201801"
firstYear = yearweek[0]
firstYear

# %%
###문자열 앞 4글자 출력 :가 연속. 0123 4미포함
yearweek[0:4]

# %%
### 뒷 네글자 추출 
yearweek[4:]

# %%
###절대 수 입력 후 절대 수 뒷글자만 추출. 절대수는 대문자로 설정.
YEARLEN = 4

yearweek[YEARLEN:]

# %%
###문자열 개수세기 
yearweek = "2017W28"
print(yearweek.count('W'))

###문자열 위치확인
print(yearweek.index('W'))
delimeter=yearweek.index('W') 


###특정 문자를 기준으로 나누기
yearweek = "2017W28"

splitVar = yearweek.split("W")

splitVar

type(splitVar)

yearweek.lower()

###delimeter 뒤에 1플러스 안하면 m 까지 같이 출력 
print(yearweek.index('W'))
delimeter=yearweek.index('W')
yearweek_new = yearweek[:delimeter]+yearweek[delimeter+1:]
print([yearweek_new])

###형변환 출력안되는 이유
numberValue = 1234
cvStrValue = str(numberValue)
print(cvStrValue)

# %%
### 실습

samsung = "Sec 2018W28 250"
stock_name = samsung[:3]
date = samsung[4:12]
value = samsung[13:16]
print(stock_name,date,value)

samsung = str("Sec 2018W28 250")
delimeter=samsung.index('W')
samsung_new = samsung[:delimeter]+samsung[delimeter+1:]
print([samsung_new])
samsung_new.upper()

###인덱스로 끊을 수 있지만, LEN 로 저장해두면 훨씬 편함

samsung = "Sec 2018W86 250"
SAMSUNGLEN = 4
stock_name = samsung[:SAMSUNGLEN]
print(stock_name)


###교수님꺼(이렇게 하면 다음 개발자가 저 숫자가 뭔지 잘 모름) --확인해
stockName = test [0:4]
date = test [4:4+8]
value = test [4+8+1:]
print(stockName)
print(date)
print(value)

###  이렇게 지정해주고  
stockLen = 3
dateLen = 8
volumeLen = 3

### 이렇게 숫자를 안쓰고 할 수 있도록 연습-----확인
stockName = test[0:stockLen]
stockName



test3 = "Sec 2018W28 250"
test3

UpperTest = test3.upper()
UpperTest

StdTest = UpperTest.replace("W","")
StdTest

splitDate = StdTest.split(" ")
splitData

type(splitDate)

# %%
### 실습 2 -값에서 최소 최대값을 뺀 평균을 average의 변수에 담아라

### 김유림
purple = [120,150,300,500,1000,100,2000]
purple1 = (min(purple))
purple2 = (max(purple))
purple.remove(purple2) 
purple.remove(purple1) 
print(purple)
end = (sum(purple)/5)
print(end)

##틀린거. 리무브 이용 인덱스 사용한 del 이 더 좋음
purple = [120,150,300,500,1000,100,2000]
purple1 = (min(purple))
purple2 = (max(purple))
del purple[purple1]
print(purple)

###교수님 Test -> 이렇게하면 안에 값이 바뀌게되면 오류가 나게 됨.
test = [120,150,300,500,1000,100,2000]

test.remove(100)
test.remove(2000)

average = sum(test)/len(test)
average

###그래서 이렇게 해야돼(1)

test = [120,150,300,500,1000,100,2000]
minValue = min(test)
print(minValue)
maxValue = max(test)
print(maxValue)

test.remove(minValue)
test.remove(maxValue)

average = sum(test)/len(test)
average


### 원래 답

test = [120,150,300,500,1000,100,2000]
minValueindex = test.index(min(test))
minValueindex

del test[minValueindex]

test

###또다른 답 

testi = [120,150,300,500,1000,100,2000]
testi.sort()
del testi[0]
del testi[len(testi)-1]
testi

###또다른 답 
testy = [120,150,300,500,1000,100,2000]
testy.sort()
del testy[len(testy)-len(testy)]
del testy[len(testy)-1]
testy = 

###딕셔너리(key:value, 반복 근데 이거말고도 쓸 수 있어서 중요도 낮음)

d=  dict(name="sec",value="3000000",address="suwon")
d

###예측할때 계절성 지수를 다뽑아 2017년몇주차에얼마나 팔렸다는 데이터를 키를 입력해서 value 를 찾을 수 있다
dict2 = {"201701":"0.2","201702":"0.5","201703":"0.7"}
dict2

dict2["201702"]

type(dict2)

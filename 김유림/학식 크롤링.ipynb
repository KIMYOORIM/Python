# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import urllib

# %%
from urllib.request import urlopen

# %%
html = urlopen

# %%
con = requests.get('http://www.kopo.ac.kr/kangseo/content.do?menu=262')

# %%
con.encoding = 'utf-8'
con
# Out:
# <Response [200]>

# %%
html = con.text
html
# Out:
# '<!DOCTYPE html>\r\n<html lang="ko" >\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0 ,maximum-scale=1.0, minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" />\r\n<meta name="author" content="폴리텍대학" />\r\n<meta name="description" content="폴리텍대학 홈페이지입니다." />\r\n<meta name="keywords" content="폴리텍대학" />\r\n<link rel="shortcut icon" href="/images/favicon.ico" type="image/x-icon" /> \r\n\r\n<!-- style & font -->\r\n<link rel="stylesheet" media="all" href="/css/reset.css?ver=2.1" />\r\n<link rel="stylesheet" media="all" href="/css/common.css?ver=2.1" />\r\n<link rel="stylesheet" media="all" href="/css/board.css?ver=2.1" />\r\n<link rel="stylesheet" media="all" href="/css/contents.css?t=CKE20180508_1" />\r\n<link rel="stylesheet" media="all" href="/css/publish.css?ver=2.1" />\r\n<link rel="stylesheet" media="all" href="/css/campus/common.css?ver=2.1" />\r\n<li
# ...

# %%
import bs4

# %%
bs = bs4.BeautifulSoup(html,'html.parser')

# %%
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1.0 ,maximum-scale=1.0, minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport"/>
# <meta content="폴리텍대학" name="author"/>
# <meta content="폴리텍대학 홈페이지입니다." name="description"/>
# <meta content="폴리텍대학" name="keywords"/>
# <link href="/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- style & font -->
# <link href="/css/reset.css?ver=2.1" media="all" rel="stylesheet"/>
# <link href="/css/common.css?ver=2.1" media="all" rel="stylesheet"/>
# <link href="/css/board.css?ver=2.1" media="all" rel="stylesheet"/>
# <link href="/css/contents.css?t=CKE20180508_1" media="all" rel="stylesheet"/>
# <link href="/css/publish.css?ver=2.1" media="all" rel="stylesheet"/>
# <link href="/css/campus/common.css?ver=2.1" media="all" rel="stylesheet"/>
# ...

# %%
colums = bs.select('thead > tr > th')
colums
# Out:
# [<th scope="col">구분</th>,
#  <th scope="col">조식</th>,
#  <th scope="col">중식</th>,
#  <th scope="col">석식</th>]

# %%
columnlist=[]
for column in colums:
    columnlist.append(column.text)
columnlist
# Out:
# ['구분', '조식', '중식', '석식']

# %%
body = bs.select('tbody > tr')
body
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-153b96465770> in <module>()
# ----> 1 body = bs.select('tbody > tr')
#       2 body
#
# NameError: name 'bs' is not defined

# %%
bubu = []

# %%
for column1 in body:
    bubu = column1.find_all('td')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7d2d9a1edbd2> in <module>()
# ----> 1 for column1 in body:
#       2     bubu = column1.find_all('td')
#
# NameError: name 'body' is not defined

# %%
bubu
# Out:
# [<td><script>document.write(getDay2('2019-04-14 00:00:00.0'));</script><br/>일요일</td>,
#  <td>
#  <span class="kcal"></span>
#  <span></span>
#  </td>,
#  <td>
#  <span class="kcal"></span>
#  <span></span>
#  </td>,
#  <td>
#  <span class="kcal"></span>
#  <span></span>
#  </td>]

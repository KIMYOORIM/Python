# %%
import pandas as pd
import numpy as np

# %%
selloutData = pd.read_csv("../Python_Fintech/Python_ST_EX/dataset/kopo_channel_seasonality_new.csv")

# %%
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
#음수는 반품으로 처리 
selloutData["NEW_QTY"] = np.where(selloutData["QTY"] < 0,0,selloutData["QTY"])

# %%
#원래 함수타입 통합 해주는데, 연산을 많이 할 것 같으면 통합 안해줘도 된다. 
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# NEW_QTY     float64
# dtype: object

# %%
#week의 값에서 즉 201901이라고 했을 때 100으로 나누면 2019.01이니까 그것만 추출.
selloutData["WEEK"] = selloutData["YEARWEEK"]%100

# %%
#함수화 시켜준다. 
def customFunction(inputColumn):
    ##inputColumn = 201601
    yearValue = inputColumn/100
    yearValue = int(yearValue)
    return yearValue

# %%
selloutData["YEAR"] = selloutData["YEARWEEK"].apply(customFunction) #apply가 없을 때

# %%
selloutData.head(1)
# Out:
#   REGIONID   PRODUCT  YEARWEEK   QTY  NEW_QTY  WEEK  YEAR
# 0      A60  PRODUCT4    201402  71.0     71.0     2  2014

# %%
refinedData = selloutData[selloutData.WEEK < 53]

# %%
refinedData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR
# 0      A60   PRODUCT4    201402     71.0     71.0     2  2014
# 1      A60  PRODUCT59    201402  22275.0  22275.0     2  2014
# 2      A60  PRODUCT34    201402   4463.0   4463.0     2  2014
# 3      A60  PRODUCT47    201402      0.0      0.0     2  2014
# 4      A60  PRODUCT56    201402     23.0     23.0     2  2014

# %%
#데이터정렬
sortKey = ["REGIONID","PRODUCT","YEARWEEK"]

# %%
sortedData = refinedData.sort_values(sortKey)

# %%
sortedData.head()
# Out:
#      REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR
# 298       A00  PRODUCT34    201401  661.0    661.0     1  2014
# 1757      A00  PRODUCT34    201402  679.0    679.0     2  2014
# 3125      A00  PRODUCT34    201403  578.0    578.0     3  2014
# 205       A00  PRODUCT34    201404  532.0    532.0     4  2014
# 4369      A00  PRODUCT34    201405  516.0    516.0     5  2014

# %%
step1Data = sortedData.reset_index(drop = True) ## 다시 정렬할 건데 전에 쓰던 인덱스도 필요하다.
step2Data = sortedData.reset_index(drop = True)  ## 기존에 있는 인덱스를 다 버리고 다시 정렬하겠다.

# %%
step1Data.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR
# 0      A00  PRODUCT34    201401  661.0    661.0     1  2014
# 1      A00  PRODUCT34    201402  679.0    679.0     2  2014
# 2      A00  PRODUCT34    201403  578.0    578.0     3  2014
# 3      A00  PRODUCT34    201404  532.0    532.0     4  2014
# 4      A00  PRODUCT34    201405  516.0    516.0     5  2014

# %%
step2Data.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR
# 0      A00  PRODUCT34    201401  661.0    661.0     1  2014
# 1      A00  PRODUCT34    201402  679.0    679.0     2  2014
# 2      A00  PRODUCT34    201403  578.0    578.0     3  2014
# 3      A00  PRODUCT34    201404  532.0    532.0     4  2014
# 4      A00  PRODUCT34    201405  516.0    516.0     5  2014

# %%
selloutData["test"] = round(selloutData["YEARWEEK"]/100)

# %%
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR    test
# 0      A60   PRODUCT4    201402     71.0     71.0     2  2014  2014.0
# 1      A60  PRODUCT59    201402  22275.0  22275.0     2  2014  2014.0
# 2      A60  PRODUCT34    201402   4463.0   4463.0     2  2014  2014.0
# 3      A60  PRODUCT47    201402      0.0      0.0     2  2014  2014.0
# 4      A60  PRODUCT56    201402     23.0     23.0     2  2014  2014.0

# %%
refinedData = selloutData[selloutData.WEEK % 100 <= 53]

# %%
refinedData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR    test
# 0      A60   PRODUCT4    201402     71.0     71.0     2  2014  2014.0
# 1      A60  PRODUCT59    201402  22275.0  22275.0     2  2014  2014.0
# 2      A60  PRODUCT34    201402   4463.0   4463.0     2  2014  2014.0
# 3      A60  PRODUCT47    201402      0.0      0.0     2  2014  2014.0
# 4      A60  PRODUCT56    201402     23.0     23.0     2  2014  2014.0

# %%
selloutData[selloutData.QTY >= 0].head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR    test
# 0      A60   PRODUCT4    201402     71.0     71.0     2  2014  2014.0
# 1      A60  PRODUCT59    201402  22275.0  22275.0     2  2014  2014.0
# 2      A60  PRODUCT34    201402   4463.0   4463.0     2  2014  2014.0
# 3      A60  PRODUCT47    201402      0.0      0.0     2  2014  2014.0
# 4      A60  PRODUCT56    201402     23.0     23.0     2  2014  2014.0

# %%
#window = 15 : 15개씩 이동평균을 내겠다. / min_periods= 1 : 데이터가 하나라도 존재하면 평균을 내겠다.

# %%
## center = True => 나를 중심으로 날개를 펴는거고 
## center = False => 내가 맨 마지막으로 가는 것

# %%
#center를 false로 하면 내위로 14개가 생기기 전까지는 nan값이 나온다.

# %%
step1Data["MA"] = step1Data.NEW_QTY.rolling(window = 15, center = True, min_periods= 1).mean()

# %%
step1Data.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR          MA
# 0      A00  PRODUCT34    201401  661.0    661.0     1  2014  520.000000
# 1      A00  PRODUCT34    201402  679.0    679.0     2  2014  514.444444
# 2      A00  PRODUCT34    201403  578.0    578.0     3  2014  516.800000
# 3      A00  PRODUCT34    201404  532.0    532.0     4  2014  503.363636
# 4      A00  PRODUCT34    201405  516.0    516.0     5  2014  490.750000

# %%
#지역, 상품, 연도별로 groupby로 정렬해서 "NEW_QTY" 이동평균을 구한다.

# %%
groupKey = ["REGIONID","PRODUCT","YEAR"]

# %%
groupData = step1Data.groupby(groupKey)[["NEW_QTY"]].mean()

# %%
groupData.head()
# Out:
#                             NEW_QTY
# REGIONID PRODUCT   YEAR
# A00      PRODUCT34 2014  275.961538
#                    2015   86.634615
#                    2016   36.576923
#          PRODUCT58 2014    2.673077
#                    2015    5.711538

# %%
groupDataResult=groupData.reset_index()

# %%
#컬럼헤더 재정의
groupDataResult.columns = ["REGIONID","PRODUCT","YEAR","GROUP"]

# %%
groupDataResult.head()
# Out:
#   REGIONID    PRODUCT  YEAR       GROUP
# 0      A00  PRODUCT34  2014  275.961538
# 1      A00  PRODUCT34  2015   86.634615
# 2      A00  PRODUCT34  2016   36.576923
# 3      A00  PRODUCT58  2014    2.673077
# 4      A00  PRODUCT58  2015    5.711538

# %%
step1Data.reset_index(drop=True)
# Out:
#        REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR  \
# 0           A00  PRODUCT34    201401    661.0    661.0     1  2014
# 1           A00  PRODUCT34    201402    679.0    679.0     2  2014
# 2           A00  PRODUCT34    201403    578.0    578.0     3  2014
# 3           A00  PRODUCT34    201404    532.0    532.0     4  2014
# 4           A00  PRODUCT34    201405    516.0    516.0     5  2014
# 5           A00  PRODUCT34    201406    423.0    423.0     6  2014
# 6           A00  PRODUCT34    201407    407.0    407.0     7  2014
# 7           A00  PRODUCT34    201408    364.0    364.0     8  2014
# 8           A00  PRODUCT34    201409    470.0    470.0     9  2014
# 9           A00  PRODUCT34    201410    538.0    538.0    10  2014
# 10          A00  PRODUCT34    201411    369.0    369.0    11  2014
# 11          A00  PRODUCT34    201412    352.0    352.0    12  2014
# 12          A00  PRODUCT34    201413    354.0    354.0    13  2014
# 13          A00  PRODUCT34    201414    312.0    312.0    14  2014
# 14          A00  PRODUCT34    201415    295.0    295.0    15  2014
# 15          A00  PRODUCT34    201416    284.0    284.0    16  2014
# 16          A00  PRODUCT34    201417    237.0    237.0    17  2014
# 17          A00  PRODUCT34    201418    180.0    180.0    18  2014
# 18          A00  PRODUCT34    201419    161.0    161.0    19  2014
# 19          A00  PRODUCT34    201420    140.0    140.0    20  2014
# 20          A00  PRODUCT34    201421    116.0    116.0    21  2014
# 21          A00  PRODUCT34    201422     98.0     98.0    22  2014
# 22          A00  PRODUCT34    201423     83.0     83.0    23  2014
# 23          A00  PRODUCT34    201424     71.0     71.0    24  2014
# 24          A00  PRODUCT34    201425     65.0     65.0    25  2014
# 25          A00  PRODUCT34    201426     60.0     60.0    26  2014
# 26          A00  PRODUCT34    201427     82.0     82.0    27  2014
# 27          A00  PRODUCT34    201428    151.0    151.0    28  2014
# 28          A00  PRODUCT34    201429    274.0    274.0    29  2014
# 29          A00  PRODUCT34    201430    532.0    532.0    30  2014
# ...         ...        ...       ...      ...      ...   ...   ...
# 123834      A77  PRODUCT12    201623   5348.0   5348.0    23  2016
# 123835      A77  PRODUCT12    201624   3275.0   3275.0    24  2016
# 123836      A77  PRODUCT12    201625   4158.0   4158.0    25  2016
# 123837      A77  PRODUCT12    201626   4815.0   4815.0    26  2016
# 123838      A77  PRODUCT12    201627   3002.0   3002.0    27  2016
# 123839      A77  PRODUCT12    201628   3319.0   3319.0    28  2016
# 123840      A77  PRODUCT12    201629   4200.0   4200.0    29  2016
# 123841      A77  PRODUCT12    201630   7120.0   7120.0    30  2016
# 123842      A77  PRODUCT12    201631   6345.0   6345.0    31  2016
# 123843      A77  PRODUCT12    201632   5863.0   5863.0    32  2016
# 123844      A77  PRODUCT12    201633   4211.0   4211.0    33  2016
# 123845      A77  PRODUCT12    201634   4019.0   4019.0    34  2016
# 123846      A77  PRODUCT12    201635   3624.0   3624.0    35  2016
# 123847      A77  PRODUCT12    201636   3742.0   3742.0    36  2016
# 123848      A77  PRODUCT12    201637   3002.0   3002.0    37  2016
# 123849      A77  PRODUCT12    201638   5583.0   5583.0    38  2016
# 123850      A77  PRODUCT12    201639  14734.0  14734.0    39  2016
# 123851      A77  PRODUCT12    201640   3603.0   3603.0    40  2016
# 123852      A77  PRODUCT12    201641   4010.0   4010.0    41  2016
# 123853      A77  PRODUCT12    201642   4292.0   4292.0    42  2016
# 123854      A77  PRODUCT12    201643   5760.0   5760.0    43  2016
# 123855      A77  PRODUCT12    201644   4109.0   4109.0    44  2016
# 123856      A77  PRODUCT12    201645   4506.0   4506.0    45  2016
# 123857      A77  PRODUCT12    201646   4255.0   4255.0    46  2016
# 123858      A77  PRODUCT12    201647   3574.0   3574.0    47  2016
# 123859      A77  PRODUCT12    201648   4152.0   4152.0    48  2016
# 123860      A77  PRODUCT12    201649   5086.0   5086.0    49  2016
# 123861      A77  PRODUCT12    201650   5846.0   5846.0    50  2016
# 123862      A77  PRODUCT12    201651   4933.0   4933.0    51  2016
# 123863      A77  PRODUCT12    201652   7551.0   7551.0    52  2016
#
#                  MA
# 0        520.000000
# 1        514.444444
# 2        516.800000
# 3        503.363636
# 4        490.750000
# 5        480.230769
# 6        468.214286
# 7        456.666667
# 8        431.533333
# 9        402.066667
# 10       375.533333
# 11       350.800000
# 12       325.733333
# 13       305.266667
# 14       284.666667
# 15       265.933333
# 16       239.333333
# 17       207.800000
# 18       187.200000
# 19       169.200000
# 20       155.666667
# 21       153.133333
# 22       168.933333
# 23       179.933333
# 24       193.000000
# 25       205.266667
# 26       217.600000
# 27       229.066667
# 28       237.600000
# 29       246.200000
# ...             ...
# 123834  4159.933333
# 123835  4272.333333
# 123836  4435.133333
# 123837  4530.533333
# 123838  4518.466667
# 123839  4527.000000
# 123840  4528.533333
# 123841  4402.866667
# 123842  4418.533333
# 123843  5182.466667
# 123844  5145.466667
# 123845  5091.800000
# 123846  5177.800000
# 123847  5340.533333
# 123848  5334.466667
# 123849  5160.200000
# 123850  5020.866667
# 123851  4868.266667
# 123852  4864.333333
# 123853  4935.466667
# 123854  5083.600000
# 123855  5163.000000
# 123856  5466.266667
# 123857  5457.928571
# 123858  4744.384615
# 123859  4839.500000
# 123860  4914.909091
# 123861  4977.200000
# 123862  4890.222222
# 123863  4987.875000
#
# [123864 rows x 8 columns]

# %%
step1Data.to_csv("./result3.csv")

# %% [markdown]
# ### 데이터합치기(속성)(merge)

# %%
#regionid, product,yearweek 를 그룹데이터 옆에 붙히기 how 확인하기 !!

# %%
#[[]] 부분에서 내가 원하는 컬럼순서대로 바꿀 수 있다. 아예 안써도 문제 없음. 
mergeResult = pd.merge(groupDataResult,step1Data,\
                      left_on = ("REGIONID","PRODUCT","YEAR"),right_on = ("REGIONID","PRODUCT","YEAR"))\
[["REGIONID", "PRODUCT","YEARWEEK","QTY","NEW_QTY","YEAR", "GROUP","WEEK","MA"]]
mergeResult.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY
# 123853    42  4935.466667
# 123854    43  5083.600000
# 123855    44  5163.000000
# 123856    45  5466.266667
# 123857    46  5457.928571
# 123858    47  4744.384615
# 123859    48  4839.500000
# 123860    49  4914.909091
# 123861    50  4977.200000
# 123862    51  4890.222222
# 123863    52  4987.875000
#
# [123864 rows x 9 columns]

# %%
mergeResult.to_csv("./result5.csv")

# %%
pwd
# Out:
# 'C:\\Users\\SMART-04\\Python_Fintech'

# %%
#groupby 를 한 상태에서 rolling 을 하겠다. 
groupKey= ["REGIONID","PRODUCT"]

# %%
mergeResult.groupby(groupKey)

# %% [markdown]
# ### 그룹바이함수만들기

# %%
#펼치려는 로직이 다른 카테고리에 영향을 주어 제대로된 추세선을 못그림.

# %%
#groupDataSet = mergeResult.groupby(groupKey)

# %%
def groupRolling(oneGroup):
    #len(list(groupDataSet.groups))
    #oneGroup = groupDataSet.get_group(list(groupDataSet.groups)[2])
    
    indexGroupData = oneGroup.reset_index(drop=True)
    indexGroupData["MA3"] = indexGroupData["NEW_QTY"].rolling(window = 5,center=True).mean()
    
    return indexGroupData

# %%
finalResult = mergeResult.groupby(groupKey).apply(groupRolling)

# %%
finalResult.head()
# Out:
#                      REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  YEAR  \
# REGIONID PRODUCT
# A00      PRODUCT34 0      A00  PRODUCT34    201401  661.0    661.0  2014
#                    1      A00  PRODUCT34    201402  679.0    679.0  2014
#                    2      A00  PRODUCT34    201403  578.0    578.0  2014
#                    3      A00  PRODUCT34    201404  532.0    532.0  2014
#                    4      A00  PRODUCT34    201405  516.0    516.0  2014
#
#                            GROUP  WEEK          MA    MA3
# REGIONID PRODUCT
# A00      PRODUCT34 0  275.961538     1  520.000000    NaN
#                    1  275.961538     2  514.444444    NaN
#                    2  275.961538     3  516.800000  593.2
#                    3  275.961538     4  503.363636  545.6
#                    4  275.961538     5  490.750000  491.2

# %%
finalResult.to_csv("./finalResult.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-57-08b0ac513273> in <module>()
# ----> 1 finalResult.to_csv("./finalResult.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: './finalResult.csv'

# %% [markdown]
# ## 설명

# %%
# 롤링함수는 각지역별 함수별로 펼쳐야한다.

# %%
#총 794개의 데이터가 있는데 
len(list(groupDataSet.groups))

# %%
#그 중 그룹하나를 가지고 그룹화를 하겠다. 모든 그룹을 리스트로 만들고 그룹데이터의 0번째 데이터를 가져오겠다. 0번째 함수에 대해서만 롤링을 펼치겠다 .
oneGroup = groupDataSet.get_group(list(groupDataSet.groups)[0])

# %%
oneGroup.head()

# %%
scdGroup = groupDataSet.get_group(list(groupDataSet.groups)[0])

# %%
step1Data["MA2"] = scdGroup.NEW_QTY.rolling(window = 15, center = True, min_periods= 1).mean()

# %%
step1Data

# %%
step1Data.to_csv("./result6.csv")

# %%
#컬럼삭제 
#del step1Data["MA2"]

# %%
step1Data

# %% [markdown]
# ### 데이터합치기 기준 확인

# %%
#step1을 기준으로 regionid로

# %%
leftData = step1Data

# %%
#컬럼이 동일한 경우 left,right on을 따로 안써주어도 된다. 
MGD = pd.merge(leftData,groupDataResult,how = "left",on="REGIONID")
#데이터를 합칠 때는 항상 한줄에 하나씩만 나오게 키를 설정해야한다. 같은 정보가 중복 되지 않도록.

# %%
MGD.head()

# %%
len(leftData)

# %%
#중복되는 값도 붙기때문에 데이터양이 많아진다. 
len(MGD)

# %%
joinKey = ["REGIONID","PRODUCT"]

# %%
PRD = pd.merge(leftData,groupDataResult,how = "left",on= joinKey)

# %%
len(PRD)

# %% [markdown]
# ###  1. 파일데이터 불러오기

# %%
import pandas as pd

# %%
regionData = pd.read_csv("../Python_ST_EX/dataset/kopo_region_mst.csv")

# %%
#앞 다섯개만
regionData.head(5)
# Out:
#   REGIONID REGIONNAME
# 0      A00     AFRICA
# 1      A01    AMERICA
# 2      A02      KOREA
# 3      A03     GERMAN
# 4      A04     BRAZIL

# %% [markdown]
# ### 2. 한글

# %%
#이게안되니까
import pandas as pd

# %%
pd.read_csv("../Python_ST_EX/dataset/kopo_region_mst_hangul.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbe in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-2fbda660fbf1> in <module>()
# ----> 1 pd.read_csv("../Python_ST_EX/dataset/kopo_region_mst_hangul.csv")
#
# ...

# %%
#이렇게 수정 (encoding 이용)
import pandas as pd

# %%
kopoHangul=pd.read_csv("../Python_ST_EX/dataset/kopo_region_mst_hangul.csv",encoding="ms949")

# %%
kopoHangul.head(5)

# %% [markdown]
# ### 3. 데이터내보내기

# %%
import pandas as pd

# %%
custom=pd.read_csv("../Python_ST_EX/dataset/kopo_customerdata.csv")

# %%
#줄이길어서 head로 줄임
custom.head(6)

# %% [markdown]
# ### 여기부터 다시

# %%
import pandas as pd

# %%
customerData=pd.read_csv("../Python_ST_EX/dataset/customerdata.csv")

# %%
customerData.head(6)

# %% [markdown]
# ### 5. 컬럼해더 재정의

# %%
customerData2=pd.read_csv("../Python_ST_EX/dataset/customerdata2.csv")
customerData2
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE            CUSTT0
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
customerData2.columns = ["CUSTID","AVGPRICE","EMI","DEVICECOUNT","PRODUCTAGE","C"]

# %%
customerData2
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE                 C
# 0    A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
import pandas as pd

# %%
customerData=pd.read_csv("../Python_ST_EX/dataset/customerdata.csv")

# %%
#데이터 내보내기
customerData.to_csv("./cust", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4c8937b7b296> in <module>()
#       1 #데이터 내보내기
# ----> 2 customerData.to_csv("../Python_ST_EX/dataset/customerdata5.csv", index=False)
#
# NameError: name 'customerData' is not defined

# %%
customerData5 = pd.read_csv("../Python_ST_EX/dataset/customerdata5.csv")

# %%
customerData5.head(5)
